# %% [markdown]
# # Maternal health indices in Nigeria

# %% [markdown]
# Maternal and child health are issues dear to me. It seems plausible that every Nigerian has lost someone, or knows someone who has lost someone to maternal mortality. As my first project towards the Data Scientist nanodegree, I decided to take a look at the several indices that are believed to contribute to maternal health issues

# %% [markdown]
# I downloaded this data from https://databank.worldbank.org/indicator and filtered "health, nutrition and population" parameters specific to Nigeria

# %%
pwd
# Out:
# 'C:\\Users\\chidimmpe\\Downloads'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
Nigeria_m_h_df= pd.read_csv("Nigeria data.csv",)

Nigeria_m_h_df.head()
# Out:
#                                      Series Name        Series Code  \
# 0       Survival to age 65, female (% of cohort)  SP.DYN.TO65.FE.ZS
# 1         Survival to age 65, male (% of cohort)  SP.DYN.TO65.MA.ZS
# 2  Completeness of birth registration, rural (%)  SP.REG.BRTH.RU.ZS
# 3  Completeness of birth registration, urban (%)  SP.REG.BRTH.UR.ZS
# 4         Completeness of birth registration (%)     SP.REG.BRTH.ZS
#
#   Country Name Country Code 1960 [YR1960] 1961 [YR1961] 1962 [YR1962]  \
# 0      Nigeria          NGA    29.3704606    29.9731888     30.575917
# 1      Nigeria          NGA    24.0753158    24.6601924     25.245069
# 2      Nigeria          NGA            ..            ..            ..
# 3      Nigeria          NGA            ..            ..            ..
# 4      Nigeria          NGA            ..            ..            ..
#
#   1963 [YR1963] 1964 [YR1964] 1965 [YR1965]  ... 2012 [YR2012] 2013 [YR2013]  \
# ...

# %% [markdown]
# The column names with years do ont look very nice. I especially do not like the repeated dates in squared brackets

# %%
list(Nigeria_m_h_df.columns)
# Out:
# ['Series Name',
#  'Series Code',
#  'Country Name',
#  'Country Code',
#  '1960 [YR1960]',
#  '1961 [YR1961]',
#  '1962 [YR1962]',
#  '1963 [YR1963]',
#  '1964 [YR1964]',
#  '1965 [YR1965]',
#  '1966 [YR1966]',
#  '1967 [YR1967]',
#  '1968 [YR1968]',
#  '1969 [YR1969]',
#  '1970 [YR1970]',
#  '1971 [YR1971]',
#  '1972 [YR1972]',
#  '1973 [YR1973]',
#  '1974 [YR1974]',
#  '1975 [YR1975]',
#  '1976 [YR1976]',
#  '1977 [YR1977]',
#  '1978 [YR1978]',
#  '1979 [YR1979]',
#  '1980 [YR1980]',
#  '1981 [YR1981]',
#  '1982 [YR1982]',
#  '1983 [YR1983]',
#  '1984 [YR1984]',
#  '1985 [YR1985]',
#  '1986 [YR1986]',
#  '1987 [YR1987]',
#  '1988 [YR1988]',
#  '1989 [YR1989]',
#  '1990 [YR1990]',
#  '1991 [YR1991]',
#  '1992 [YR1992]',
#  '1993 [YR1993]',
#  '1994 [YR1994]',
#  '1995 [YR1995]',
#  '1996 [YR1996]',
#  '1997 [YR1997]',
#  '1998 [YR1998]',
#  '1999 [YR1999]',
#  '2000 [YR2000]',
#  '2001 [YR2001]',
#  '2002 [YR2002]',
#  '2003 [YR2003]',
#  '2004 [YR2004]',
#  '2005 [YR2005]',
# ...

# %% [markdown]
# Changing the years to something more visually appealing

# %%
Nigeria_m_h_df = Nigeria_m_h_df.rename(columns= {"1960 [YR1960]": "1960",
                                                "1961 [YR1961]":"1961",
                                                "1962 [YR1962]" :"1962",
                                                "1963 [YR1963]": "1963",
                                                "1964 [YR1964]":"1964",
                                                "1965 [YR1965]":"1965",
                                                "1966 [YR1966]":"1966",
                                                "1967 [YR1967]":"1967",
                                                "1968 [YR1968]":"1968",
                                                "1969 [YR1969]":"1967",
                                                "1970 [YR1970]":"1970",
                                                "1971 [YR1971]":"1971",
                                                "1972 [YR1972]":"1972",
                                                "1973 [YR1973]":"1973",
                                                "1974 [YR1974]":"1974",
                                                "1975 [YR1975]":"1975",
                                                "1976 [YR1976]":"1976",
                                                "1977 [YR1977]":"1977",
                                                "1978 [YR1978]":"1978",
                                                "1979 [YR1979]":"1979",
                                                "1980 [YR1980]":"1980",
                                                 "1981 [YR1981]":"1981",
                                                 "1982 [YR1982]": "1982",
                                                 "1983 [YR1983]":"1983",
                                                 "1984 [YR1984]":"1984",
                                                 "1985 [YR1985]":"1985",
                                                 "1986 [YR1986]":"1986",
                                                 "1987 [YR1987]": "1987",
                                                 "1988 [YR1988]":"1988",
                                                 "1989 [YR1989]":"1989",
                                                 "1990 [YR1990]":"1990",
                                                 "1991 [YR1991]":"1991",
                                                 "1992 [YR1992]":"1992",
                                                 "1993 [YR1993]":"1993",
                                                 "1994 [YR1994]":"1994",
                                                 "1995 [YR1995]": "1995",
                                                 "1996 [YR1996]":"1996",
                                                 "1997 [YR1997]":"1997",
                                                 "1998 [YR1998]":"1998",
                                                 "1999 [YR1999]":"1999",
                                                 "2000 [YR2000]":"2000",
                                                 "2001 [YR2001]":"2001",
                                                 "2002 [YR2002]":"2002",
                                                 "2003 [YR2003]":"2003",
                                                 "2004 [YR2004]":"2004",
                                                 "2005 [YR2005]":"2005",
                                                 "2006 [YR2006]":"2006",
                                                 "2007 [YR2007]":"2007",
                                                 "2008 [YR2008]":"2008",
                                                 "2009 [YR2009]":"2009",
                                                 "2010 [YR2010]":"2010",
                                                 "2011 [YR2011]":"2011",
                                                 "2012 [YR2012]":"2012",
                                                 "2013 [YR2013]":"2013",
                                                 "2014 [YR2014]":"2014",
                                                 "2015 [YR2015]":"2015",
                                                 "2016 [YR2016]":"2016",
                                                 "2017 [YR2017]":"2017",
                                                 "2018 [YR2018]":"2018",
                                                 "2019 [YR2019]":"2019",
                                                 "2020 [YR2020]":"2020",
                                                 "2021 [YR2021]":"2021"
                                                 
                                                })
Nigeria_m_h_df.head()
# Out:
#                                      Series Name        Series Code  \
# 0       Survival to age 65, female (% of cohort)  SP.DYN.TO65.FE.ZS
# 1         Survival to age 65, male (% of cohort)  SP.DYN.TO65.MA.ZS
# 2  Completeness of birth registration, rural (%)  SP.REG.BRTH.RU.ZS
# 3  Completeness of birth registration, urban (%)  SP.REG.BRTH.UR.ZS
# 4         Completeness of birth registration (%)     SP.REG.BRTH.ZS
#
#   Country Name Country Code        1960        1961       1962        1963  \
# 0      Nigeria          NGA  29.3704606  29.9731888  30.575917  31.0626312
# 1      Nigeria          NGA  24.0753158  24.6601924  25.245069   25.719723
# 2      Nigeria          NGA          ..          ..         ..          ..
# 3      Nigeria          NGA          ..          ..         ..          ..
# 4      Nigeria          NGA          ..          ..         ..          ..
#
#          1964        1965  ...       2012        2013        2014        2015  \
# ...

# %% [markdown]
# Looks good, but need to confirm if all the columns were changed

# %%
list(Nigeria_m_h_df.columns)
# Out:
# ['Series Name',
#  'Series Code',
#  'Country Name',
#  'Country Code',
#  '1960',
#  '1961',
#  '1962',
#  '1963',
#  '1964',
#  '1965',
#  '1966',
#  '1967',
#  '1968',
#  '1967',
#  '1970',
#  '1971',
#  '1972',
#  '1973',
#  '1974',
#  '1975',
#  '1976',
#  '1977',
#  '1978',
#  '1979',
#  '1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021']

# %% [markdown]
# Country code and Series code do not appear relevant to this work so I would be dropping those columns. Same applies to "Country Name" since every data belongs to Nigeria

# %%
Nigeria_m_h_df = Nigeria_m_h_df.drop(["Series Code", "Country Code", "Country Name"], axis = 1)
Nigeria_m_h_df.head()
# Out:
#                                      Series Name        1960        1961  \
# 0       Survival to age 65, female (% of cohort)  29.3704606  29.9731888
# 1         Survival to age 65, male (% of cohort)  24.0753158  24.6601924
# 2  Completeness of birth registration, rural (%)          ..          ..
# 3  Completeness of birth registration, urban (%)          ..          ..
# 4         Completeness of birth registration (%)          ..          ..
#
#         1962        1963        1964        1965        1966       1967  \
# 0  30.575917  31.0626312  31.5493454  32.0360596  32.5227738  33.009488
# 1  25.245069   25.719723   26.194377   26.669031   27.143685  27.618339
# 2         ..          ..          ..          ..          ..         ..
# 3         ..          ..          ..          ..          ..         ..
# 4         ..          ..          ..          ..          ..         ..
#
#          1968  ...       2012        2013        2014        2015        2016  \
# ...

# %% [markdown]
# Need to take a look at the unique Serie Names to determine those that may be relevant to maternal health

# %%
np.unique(list(Nigeria_m_h_df["Series Name"]))
# Out:
# array(['AIDS estimated deaths (UNAIDS estimates)',
#        'ARI treatment (% of children under 5 taken to a health provider)',
#        'Adolescent fertility rate (births per 1,000 women ages 15-19)',
#        'Adults (ages 15+) and children (0-14 years) living with HIV',
#        'Adults (ages 15+) and children (ages 0-14) newly infected with HIV',
#        'Adults (ages 15+) living with HIV',
#        'Adults (ages 15-49) newly infected with HIV',
#        'Age at first marriage, female', 'Age at first marriage, male',
#        'Antiretroviral therapy coverage (% of people living with HIV)',
#        'Antiretroviral therapy coverage for PMTCT (% of pregnant women living with HIV)',
#        'Births attended by skilled health staff (% of total)',
#        'Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)',
#        'Cause of death, by injury (% of total)',
#        'Cause of death, by non-communicable diseases (% of total)',
# ...

# %%
Nigeria_m_h_df=Nigeria_m_h_df.set_index("Series Name")
Nigeria_m_h_df.head()
# Out:
#                                                      1960        1961  \
# Series Name
# Survival to age 65, female (% of cohort)       29.3704606  29.9731888
# Survival to age 65, male (% of cohort)         24.0753158  24.6601924
# Completeness of birth registration, rural (%)          ..          ..
# Completeness of birth registration, urban (%)          ..          ..
# Completeness of birth registration (%)                 ..          ..
#
#                                                     1962        1963  \
# Series Name
# Survival to age 65, female (% of cohort)       30.575917  31.0626312
# Survival to age 65, male (% of cohort)         25.245069   25.719723
# Completeness of birth registration, rural (%)         ..          ..
# Completeness of birth registration, urban (%)         ..          ..
# Completeness of birth registration (%)                ..          ..
#
#                                                      1964        1965  \
# Series Name
# ...

# %% [markdown]
# Creating as subsett of the data to include those likely relevant to maternal health outcomes

# %%
New_df= Nigeria_m_h_df.loc[["Births attended by skilled health staff (% of total)",
                           "Community health workers (per 1,000 people)",
                            "Contraceptive prevalence, any method (% of married women ages 15-49)",
                             "Contraceptive prevalence, any modern method (% of married women ages 15-49)",
                             "Demand for family planning satisfied by modern methods (% of married women with demand for family planning)",
                            "Labor force, female (% of total labor force)",
                             "Lifetime risk of maternal death (%)",
                             "Literacy rate, adult female (% of females ages 15 and above)",
                              "Maternal mortality ratio (modeled estimate, per 100,000 live births)",
                               "Number of maternal deaths",
                               "Nurses and midwives (per 1,000 people)",
                               "Pregnant women receiving prenatal care (%)",
                               "Pregnant women receiving prenatal care of at least four visits (% of pregnant women)",
                               "Postnatal care coverage (% mothers)",
                               "Physicians (per 1,000 people)",
                               "Teenage mothers (% of women ages 15-19 who have had children or are currently pregnant)",
                               "Wanted fertility rate (births per woman)"
                              ]]

print(New_df)
# Out:
#                                                      1960 1961 1962 1963 1964  \
# Series Name
# Births attended by skilled health staff (% of t...     ..   ..   ..   ..   ..
# Community health workers (per 1,000 people)            ..   ..   ..   ..   ..
# Contraceptive prevalence, any method (% of marr...     ..   ..   ..   ..   ..
# Contraceptive prevalence, any modern method (% ...     ..   ..   ..   ..   ..
# Demand for family planning satisfied by modern ...     ..   ..   ..   ..   ..
# Labor force, female (% of total labor force)           ..   ..   ..   ..   ..
# Lifetime risk of maternal death (%)                    ..   ..   ..   ..   ..
# Literacy rate, adult female (% of females ages ...     ..   ..   ..   ..   ..
# Maternal mortality ratio (modeled estimate, per...     ..   ..   ..   ..   ..
# Number of maternal deaths                              ..   ..   ..   ..   ..
# Nurses and midwives (per 1,000 people)                 ..   ..   ..   ..   ..
# ...

# %% [markdown]
# A proper look at the dataframe shows many Series have no values. There is also no input for 2021. So I will have to drop the affected series and rows

# %% [markdown]
# Now pivoting the dataframe to make it suitable for analyses.

# %%
New_df= New_df.loc[["Labor force, female (% of total labor force)", "Lifetime risk of maternal death (%)", 
                    "Maternal mortality ratio (modeled estimate, per 100,000 live births)", "Number of maternal deaths" ]]
New_df.head()
# Out:
#                                                    1960 1961 1962 1963 1964  \
# Series Name
# Labor force, female (% of total labor force)         ..   ..   ..   ..   ..
# Lifetime risk of maternal death (%)                  ..   ..   ..   ..   ..
# Maternal mortality ratio (modeled estimate, per...   ..   ..   ..   ..   ..
# Number of maternal deaths                            ..   ..   ..   ..   ..
#
#                                                    1965 1966 1967 1968 1967  \
# Series Name
# Labor force, female (% of total labor force)         ..   ..   ..   ..   ..
# Lifetime risk of maternal death (%)                  ..   ..   ..   ..   ..
# Maternal mortality ratio (modeled estimate, per...   ..   ..   ..   ..   ..
# Number of maternal deaths                            ..   ..   ..   ..   ..
#
#                                                     ...              2012  \
# Series Name                                         ...
# ...

# %%
print(New_df)
# Out:
#                                                    1960 1961 1962 1963 1964  \
# Series Name
# Labor force, female (% of total labor force)         ..   ..   ..   ..   ..
# Lifetime risk of maternal death (%)                  ..   ..   ..   ..   ..
# Maternal mortality ratio (modeled estimate, per...   ..   ..   ..   ..   ..
# Number of maternal deaths                            ..   ..   ..   ..   ..
#
#                                                    1965 1966 1967 1968 1967  \
# Series Name
# Labor force, female (% of total labor force)         ..   ..   ..   ..   ..
# Lifetime risk of maternal death (%)                  ..   ..   ..   ..   ..
# Maternal mortality ratio (modeled estimate, per...   ..   ..   ..   ..   ..
# Number of maternal deaths                            ..   ..   ..   ..   ..
#
#                                                     ...              2012  \
# Series Name                                         ...
# ...

# %% [markdown]
# There is almost no input from 1960 to 2011. And no input in 2021 too. These columns will be dropped

# %%
New_df= New_df.drop(['1960', '1970',], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\CHIDIM~1\AppData\Local\Temp/ipykernel_18640/3351976925.py in <module>
# ----> 1 New_df= New_df.drop(['1960', '1970',], axis = 1)
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
New_df = New_df.reset_index()

# %%
New_df = pd.melt(New_df, id_vars =["Series Name"], var_name = "Year", value_name ="Rate")
New_df.head()
# Out:
#                                          Series Name  Year Rate
# 0       Labor force, female (% of total labor force)  1960   ..
# 1                Lifetime risk of maternal death (%)  1960   ..
# 2  Maternal mortality ratio (modeled estimate, pe...  1960   ..
# 3                          Number of maternal deaths  1960   ..
# 4       Labor force, female (% of total labor force)  1961   ..

# %%
New_df["Rate"].min()
# Out:
# '..'

# %%
New_df["Rate"].max()
# Out:
# '996'

# %%
list(New_df["Series Name"].unique())
# Out:
# ['Labor force, female (% of total labor force)',
#  'Lifetime risk of maternal death (%)',
#  'Maternal mortality ratio (modeled estimate, per 100,000 live births)',
#  'Number of maternal deaths']

# %%
fig, ax =plt.subplots(figsize= (30,20), dpi = 80)
sns.set_theme(style="darkgrid")

sns.lineplot(y= "Rate", x= "Year", data = New_df, hue = "Series Name", linewidth =5, style = "Series Name", )

ax.set_title("Rates across the years", fontdict = {"fontsize":50})
ax.set_xlabel("Year", fontsize = 50)
ax.set_ylabel("Numbers", fontsize = 50)
ax.tick_params(labelsize = 20)
ax.legend(loc= "upper right", bbox_to_anchor=(1.6,1))
ax.grid(visible = True, which = "minor",  linewidth= 0.25 )
ax.autoscale(enable= True, axis = "both")

# %%
#ax.legend(labels = ["Births per staff", "Health workers per 1000", "Contraceptive, any method", "Contraceptives, modern methods",
            #"Demand family planning", "Labor force per female", "Lifetime risk of maternal death", " Female literacy rate",
            #"Maternal mortality ratio", "Number of maternal deaths", "Nurses and midwives per 1000", "Pregnant recieving prenatacl care",
                      # ""])
